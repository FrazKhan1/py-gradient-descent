# %%
import pandas as pd
import matplotlib.pyplot as mtb
import seaborn as sb

data = pd.read_csv("sales.csv")

# data.head(10)

# %%
sales = data.query("Sales>1000")["Sales"].to_frame()

# %%
mtb.figure(figsize=(18, 6))
sb.histplot(sales, bins=100, color="red")
mtb.title("Distribution of Sales")
mtb.xlabel("Sales")
mtb.ylabel("Distribution")
mtb.grid(axis="y", linestyle="--", alpha=.7)
mtb.show()

# %%
top_sc = data.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False).head(10)

# %%
mtb.figure(figsize=(12, 6))
sb.barplot(x=top_sc.index, y=top_sc.values, color="red")
mtb.title("Top 10 Sub-Categories by Profit")
mtb.xlabel("Sub-Category")
mtb.ylabel("Profit")
mtb.grid(axis="y", linestyle="--", alpha=.7)
mtb.show()

# %%
sales_by_sp = data.groupby("Country/Region")["Sales"].sum()

# %%
mtb.figure(figsize=(12, 6))
sb.barplot(x=sales_by_sp.index, y=sales_by_sp.values, color="blue")
mtb.title("Sales by Country/Region")
mtb.xlabel("Country/Region")
mtb.ylabel("Sales")
mtb.grid(axis="y", linestyle="--", alpha=.7)
mtb.show()

# %%
data.head(1)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2021-103800  03-01-2021  07-01-2021  Standard Class    DP-13000
#
#    Customer Name   Segment Country/Region     City  ... Postal Code   Region  \
# 0  Darren Powers  Consumer  United States  Houston  ...       77095  Central
#
#         Product ID         Category Sub-Category  \
# 0  OFF-PA-10000174  Office Supplies        Paper
#
#                                         Product Name   Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448         2
#
#    Discount  Profit
# 0       0.2  5.5512
#
# [1 rows x 21 columns]

# %%
customer_by_q = data.groupby("Customer Name")["Quantity"].sum().sort_values(ascending=False).head(25)
# filtered_cusomter = customer_by_q[customer_by_q <= 10]

# %%
customer_by_q
# Out:
# Customer Name
# William Brown          154
# Jane Waco              154
# Jonathan Doherty       150
# Ben Ferrer             146
# John Lee               143
# Paul Prost             138
# Greg Guthrie           133
# Steven Cartwright      133
# Joe Elijah             129
# Emily Phan             124
# Chloris Kastensmidt    122
# Cassandra Brandow      122
# Xylona Preis           121
# Edward Hooks           120
# Matt Abelman           117
# Sally Hughsby          113
# Ken Lonsdale           113
# Noel Staavos           113
# Lena Cacioppo          113
# Seth Vernon            109
# Clytie Kelty           108
# Pete Kriz              107
# Clay Ludtke            106
# Greg Tran              106
# Maribeth Schnelling    105
# Name: Quantity, dtype: int64

# %%
mtb.figure(figsize=(18, 8))
mtb.pie(customer_by_q, labels=customer_by_q.index,autopct=lambda p: f'{p * sum(customer_by_q) / 100:.0f}' , startangle=90  )
mtb.title("Customer Distribution by Quantity")
mtb.legend()
mtb.show()
